# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import timedelta
from weather_data_reader import WeatherDataReader

# %%
reader = WeatherDataReader(
    bucket=os.getenv('AWS_BUCKET_NAME', 'manoa-raspi-weather'),
    bronze_prefix="samples",
    silver_prefix="silver",
    region="us-west-2"
)

# %%
df = reader.get_readings(hours=24*7, layer="silver")
# Out:
# /home/jovyan/work/weather_data_reader.py:221: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat(all_data, ignore_index=True)

# %%
df
# Out:
#                               ts  temp_c  temp_f  humidity  pressure  \
# 0    2025-10-10T21:34:45.080695Z   29.10   84.37     54.78   1016.29
# 1    2025-10-10T21:49:56.352157Z   29.37   84.86     54.75   1016.04
# 2    2025-10-10T22:05:07.604259Z   29.64   85.36     53.86   1015.86
# 3    2025-10-10T22:20:19.008979Z   29.77   85.59     51.22   1015.67
# 4    2025-10-10T22:35:30.688805Z   29.09   84.37     54.84   1015.56
# ..                           ...     ...     ...       ...       ...
# 630  2025-10-17T20:18:23.024828Z   28.49   83.28     50.93   1016.41
# 631  2025-10-17T20:33:33.959730Z   28.85   83.92     50.74   1016.32
# 632  2025-10-17T20:48:47.189128Z   29.02   84.23     50.53   1016.13
# 633  2025-10-17T21:03:58.564760Z   29.18   84.52     50.14   1016.19
# 634  2025-10-17T21:19:09.727730Z   28.83   83.89     50.23   1015.78
#
#      temp_from_humidity  temp_from_pressure  cpu_temp  dew_point_c  \
# 0                 38.01               35.30     49.66        19.06
# 1                 38.18               35.57     48.20        19.30
# 2                 38.39               35.84     48.20        19.28
# 3                 38.67               35.97     48.69        18.60
# 4                 37.88               35.29     45.76        19.07
# ..                  ...                 ...       ...          ...
# 630               37.52               34.69     44.30        17.33
# 631               37.77               35.05     44.30        17.60
# 632               38.07               35.22     44.30        17.69
# 633               38.18               35.38     44.79        17.72
# 634               37.69               35.03     43.82        17.42
#
#      dew_point_f comfort_index  pressure_trend_3h  pressure_trend_6h  \
# 0          66.30       too_hot                NaN                NaN
# 1          66.74       too_hot                NaN                NaN
# 2          66.71       too_hot                NaN                NaN
# 3          65.48       too_hot                NaN                NaN
# 4          66.32       too_hot                NaN                NaN
# ..           ...           ...                ...                ...
# 630        63.20       too_hot                NaN                NaN
# 631        63.69       too_hot                NaN                NaN
# 632        63.85       too_hot                NaN                NaN
# 633        63.89       too_hot                NaN                NaN
# 634        63.36       too_hot                NaN                NaN
#
#     pressure_trend_label  daily_temp_min  daily_temp_max  daily_temp_avg  \
# 0            calculating             NaN             NaN             NaN
# 1            calculating             NaN             NaN             NaN
# 2            calculating             NaN             NaN             NaN
# 3            calculating             NaN             NaN             NaN
# 4            calculating             NaN             NaN             NaN
# ..                   ...             ...             ...             ...
# 630          calculating             NaN             NaN             NaN
# 631          calculating             NaN             NaN             NaN
# 632          calculating             NaN             NaN             NaN
# 633          calculating             NaN             NaN             NaN
# 634          calculating             NaN             NaN             NaN
#
#      daily_humidity_avg  daily_pressure_avg                        timestamp
# 0                   NaN                 NaN 2025-10-10 21:34:45.080695+00:00
# 1                   NaN                 NaN 2025-10-10 21:49:56.352157+00:00
# 2                   NaN                 NaN 2025-10-10 22:05:07.604259+00:00
# 3                   NaN                 NaN 2025-10-10 22:20:19.008979+00:00
# 4                   NaN                 NaN 2025-10-10 22:35:30.688805+00:00
# ..                  ...                 ...                              ...
# 630                 NaN                 NaN 2025-10-17 20:18:23.024828+00:00
# 631                 NaN                 NaN 2025-10-17 20:33:33.959730+00:00
# 632                 NaN                 NaN 2025-10-17 20:48:47.189128+00:00
# 633                 NaN                 NaN 2025-10-17 21:03:58.564760+00:00
# 634                 NaN                 NaN 2025-10-17 21:19:09.727730+00:00
#
# [635 rows x 20 columns]

# %%
df['ts'] = pd.to_datetime(df['ts'])
df.set_index('ts', inplace=True)

# %%
df[['temp_f']].plot()
# Out:
# <Axes: xlabel='ts'>

# %%
df['unix_ts'] = df.index.astype(np.int64) / 10**9

# %%
line_coef = np.polyfit(df['unix_ts'],df['temp_f'],1)
print(line_coef)

polynomial = np.poly1d(line_coef)
# Out:
# [-3.66867955e-06  6.54514107e+03]
